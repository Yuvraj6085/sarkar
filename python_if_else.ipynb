# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvraj6085/sarkar/blob/main/python_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mood = input("Yashika ka mood kya hai? (happy/sad/angry): ")

if mood == "happy":
    print("Aaj Yashika bahut cute lag rahi hai")
elif mood == "sad":

    print("Koi baat nahi, main hoon na")
elif mood == "angry":
    print(" Sorry bolo aur chocolate do")
else:
    print(" Mood samajh nahi aaya")
# Out:
# Yashika ka mood kya hai? (happy/sad/angry): h
#  Mood samajh nahi aaya

# %%
name = input("Enter name: ")

if name.lower() == "yashika":
    print(" Special person detected")
elif name.lower() == "friend":
    print(" Just a friend")
else:
    print(" Normal human")
# Out:
# Enter name: yashika
#  Special person detected

# %%
rating = int(input("Yashika ki cuteness rating (1-10): "))

if rating >= 9:
    print(" Too cute to handle")
elif rating >= 7:
    print(" Very cute")
elif rating >= 5:
    print(" Cute")
else:
    print(" Impossible input")
# Out:
# Yashika ki cuteness rating (1-10): 4
#  Impossible input

# %%
reply_time = int(input("Reply time (minutes): "))

if reply_time <= 5:
    print(" Fast reply = caring person")
elif reply_time <= 30:
    print(" Busy but important")
else:
    print("Seen zone activated")
# Out:
# Reply time (minutes): 90
# Seen zone activated

# %%
trust = input("Trust level (high/medium/low): ")

if trust == "high":
    print("Strong bonding")
elif trust == "medium":
    print(" Growing ")
else:
    print(" Just friends")
# Out:
# Trust level (high/medium/low): high
# Strong bonding

# %%
n = int(input())
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# 4
# Even

# %%
n = int(input())
if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# 6
# Positive

# %%
age = int(input())
if age >= 18:
    print("Can Vote")
else:
    print("Cannot Vote")
# Out:
# 7
# Cannot Vote

# %%
a,b = map(int,input().split())
if a > b:
    print(a)
else:
    print(b)
# Out:
# 6 7
# 7

# %%
pwd = input()
if pwd == "yashika123":
    print("Access Granted ")
else:
    print("Wrong Password")
# Out:
# yashika123
# Access Granted ❤️

# %%
m = int(input())
if m >= 90:
    print("A")
elif m >= 75:
    print("B")
elif m >= 60:
    print("C")
else:
    print("Fail")
# Out:
# 60
# C

# %%
y = int(input())
if y % 400 == 0 or (y % 4 == 0 and y % 100 != 0):
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# 400
# Leap Year

# %%
t = int(input())
if t > 30:
    print("Hot")
elif t >= 20:
    print("Normal")
else:
    print("Cold")
# Out:
# 56
# Hot

# %%
c = input()
if c in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# 67
# Consonant

# %%
user = input()
if user == "yashika":
    print("Welcome ")
else:
    print("Invalid User")
# Out:
# 78
# Invalid User

# %%
n = int(input())
if n % 2 == 0:
    print(n*n)
else:
    print(n*n*n)
# Out:
# 2
# 4

# %%
n = int(input())
if n % 5 == 0 and n % 11 == 0:
    print("Yes")
else:
    print("No")
# Out:
# 99
# No

# %%
n = int(input())
if n < 0:
    print(-n)
else:
    print(n)
# Out:
# 3
# 3

# %%
a,b = map(int,input().split())
op = input()
if op == "+":
    print(a+b)
elif op == "-":
    print(a-b)
elif op == "*":
    print(a*b)
elif op == "/":
    print(a/b)
else:
    print("Invalid")
# Out:
# 1 2
# 23
# Invalid

# %%
a,b = map(int,input().split())
op = input()
if op == "+":
    print(a+b)
elif op == "-":
    print(a-b)
elif op == "*":
    print(a*b)
elif op == "/":
    print(a/b)
else:
    print("Invalid")
# Out:
# 3 4
# +
# 7

# %%
cp = int(input())
sp = int(input())
if sp > cp:
    print("Profit")
elif sp < cp:
    print("Loss")
else:
    print("No Profit No Loss")
# Out:
# 6
# 7
# Profit

# %%
a,b,c = map(int,input().split())
if a>b and a>c:
    print(a)
elif b>c:
    print(b)
else:
    print(c)
# Out:
# 10 20 30
# 30

# %%
n = int(input())
if n > 0:
    print("+")
elif n < 0:
    print("-")
else:
    print("Zero")
# Out:
# 5
# +

# %%
n = int(input())
if n%3==0 or n%7==0:
    print("Yes")
else:
    print("No")
# Out:
# 9
# Yes

# %%
a,b,c = map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    print("Valid")
else:
    print("Invalid")
# Out:
# 1 2 3
# Invalid

# %%
n = int(input())
if n%2!=0 and n%5==0:
    print("Yes")
else:
    print("No")
# Out:
# 5
# Yes

# %%
amt = int(input())
if amt >= 5000:
    print(amt*0.8)
elif amt >= 3000:
    print(amt*0.9)
else:
    print(amt)
# Out:
# 6000
# 4800.0

# %%
u = int(input())
if u <= 100:
    bill = u*2
elif u <= 200:
    bill = 200 + (u-100)*3
else:
    bill = 500 + (u-200)*5
print(bill)
# Out:
# 45
# 90

# %%
salary = int(input())
if salary > 50000:
    print(salary+10000)
else:
    print(salary+5000)
# Out:
# 678888
# 688888

# %%
age = int(input())
if age < 13:
    print("Child")
elif age < 20:
    print("Teen")
else:
    print("Adult")
# Out:
# 23454
# Adult

# %%
m = int(input())
if m<0 or m>100:
    print("Invalid")
else:
    print("Valid")
# Out:
# 4
# Valid

# %%
d = int(input())
if d==1:
    print("Monday")
elif d==7:
    print("Sunday")
else:
    print("Other Day")
# Out:
# 1
# Monday

# %%
n = int(input())
if n%2==0 and n%3==0:
    print("Yes")
else:
    print("No")
# Out:
# 2
# No

# %%
n = int(input())
if n<10:
    print("Small")
elif n<100:
    print("Medium")
else:
    print("Large")
# Out:
# 10
# Medium

# %%
m = int(input())
if m >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# 60
# Pass

# %%
name = input()
if name.lower() == "yashika":
    print("Most Important ")
else:
    print("Normal Person")
# Out:
# yashika
# Most Important
